# %% [markdown]
# # Example Notebook
#
# The command `make kernel` will create a local kernel with your package in `src/{{python_package_import_name}}` ready to be imported.

# %%
import {{python_package_import_name}}
